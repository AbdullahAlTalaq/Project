# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 236.4 kB/s eta 0:00:03
#    -------------------- ------------------- 0.5/1.0 MB 236.4 kB/s eta 0:00:03
#    -------------------- ------------------- 0.5/1.0 MB 236.4 kB/s eta 0:00:03
# ...

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="D3Xlf1qhYUAr4LQ84DbN") # THIS API KEY IS REVOKED. PLEASE USE YOUR OWN API KEY
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov11:: 100%|██████████| 1338/1338 [00:02<00:00, 506.38it/s]

# %%
dataset.location
# Out:
# 'c:\\Users\\Sabic\\Downloads\\football-players-detection-1'

# %%
import shutil

shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train'
            )

shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test'
            )

shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid'
            )
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %%
import shutil
import os

base = 'football-players-detection-1/football-players-detection-1'
target = 'football-players-detection-1'

for subfolder in ['train', 'valid', 'test']:
    src = os.path.join(base, subfolder)
    dst = os.path.join(target, subfolder)
    if os.path.exists(src):
        shutil.move(src, dst)

# %%
shutil.rmtree('football-players-detection-1/football-players-detection-1')

# %%
import torch 
print(torch.cuda.is_available())
print(torch.get_device_name(1))
# Out:
# False
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 import torch
#       2 print(torch.cuda.is_available())
# ----> 3 print(torch.get_device_name(1))
#
# File c:\Users\Sabic\anaconda3\envs\llama\lib\site-packages\torch\__init__.py:2688, in __getattr__(name)
#    2685 if name in _lazy_modules:
#    2686     return importlib.import_module(f".{name}", __name__)
# -> 2688 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'torch' has no attribute 'get_device_name'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# ^C

# %%
# !yolo task=detect mode=train model=yolo8x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
